# %%
'''
Deep Learning(DL)-
  Deep learning is a subfield of AI and ML tht is inspired by the structure of a human brain.
  Deep learning algorithms attempt to draw similar conclusions as humans would by continually analyzing data with a given logical structure called Neural Network.
  So basically, Deep learning is a specialized subset of machine learning that uses multi-layered artificial neural networks to autonomously learn complex patterns from raw data.
  The main differencce between ML and DL is DL depend on statistical techniques for learning pattern where DL depends on a logical structure called neural network.
  Nueral network is a logical structure which is inspired by human brain.

  The fundamental unit of DL is perceptron which is the circle.
  The edges connect the circle is called weight. Multiple perceptron combinly create a hidden layer.

There are two main reason why deep learning getting famous more day by day.
  1) Applicability --- applicable in many fields
  2) Performance --- give better performance in many complex problem

* Deep learning is part of a broader family of machine learning methods based on artificial neural networks with representation learning.

* Deep learning algorithms uses multiple layers to progressively extract higher-level features from the raw input. For example, in image processing, lower layers may identify edges, while higher layers may identify the concepts relevant to a human such as digits or letters or faces.

** Feature learning or Representation learning is a set of techniques that allows a system to automatically discover the representations needed for feature detection or classification from raw data. This replaces manual feature enineering and allowes a machine to both learn the features and use them to perform  a specific task.
   It's basically feature engineering in ML. In ML, we manually do the feature engineering so that our model can learn from features but in DL this process is automated where DL learn the features on its own.

DL vs ML-
  1. Data dependency (DL needs more data, more data means better performance where ML can work on less data and at some point ML performance don't really icrease even if more data arrives)
  2. Hardware dependency (DL needs GPU wich is costly where ML works on CPU well which is less costly)
  3. Training time (DL needs more time on training where ML needs less time for taining)
  4. Feature selection (DL uses representation learning where it automatically extract features but in ML we need to extract features manually)
  5. Interpretability/Explainability (DL is less interpretable where ML is more interpretable)






'''
